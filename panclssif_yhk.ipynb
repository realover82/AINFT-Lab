# %%
import panclassif as pc

# %%
# homepath = '/home'
# cancerpath = '/home/cancer/'
# normalpath = '/home/normal/'

# smoothed_cancer = '/home/smoothed_cancer'
# smoothed_normal = '/home/smoothed_normal'

# %%
#You have to follow below order to work the code properly 
homepath = r'/home/yhkim/panclassif_yhk/home'
cancerpath = r'/home/yhkim/panclassif_yhk/home/cancer'
smoothed_cancer = r'/home/yhkim/panclassif_yhk/home/smoothed_cancer'
normalpath = r'/home/yhkim/panclassif_yhk/home/normal'
smoothed_normal = r'/home/yhkim/panclassif_yhk/home/smoothed_normal'

names = pc.featSelect(homepath,cancerpath,normalpath, k=5)
pc.dataProcess(homepath,names,cancerpath,smoothed_cancer,smoothed_normal, scale_mode = 'scalar')
pc.upsampled(names, homepath)
pc.binary_merge(names, homepath)
pc.multi_merge(names, homepath)
# Out:
# Feature selection process is running...
# Doing feature selection for BLCA
# Doing feature selection for BRCA
# Doing feature selection for CESC
# Doing feature selection for CHOL
# Doing feature selection for COAD
# Doing feature selection for ESCA
# Doing feature selection for HNSC
# Doing feature selection for KICH
# Doing feature selection for KIRC
# Doing feature selection for KIRP
# Doing feature selection for LIHC
# Doing feature selection for LUAD
# Doing feature selection for LUSC
# Doing feature selection for PAAD
# Doing feature selection for PCPG
# Doing feature selection for PRAD
# Doing feature selection for READ
# Doing feature selection for SARC
# Doing feature selection for STAD
# Doing feature selection for THCA
# Doing feature selection for THYM
# Doing feature selection for UCEC
# Feature selection process has ended
#
# Data process is running
# Unique genes: 105
# BLCA
# (427, 105)
# (19, 105)
# BRCA
# (1212, 105)
# (112, 105)
# CESC
# (309, 105)
# (3, 105)
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
pc.classification(homepath, RandomForestClassifier(n_estimators=100), mode="multi", save_model="RF")
# Out:
# 2023-01-05 20:04:53.513102: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-05 20:04:53.680309: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-01-05 20:04:53.713658: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
std_npy = r"/home/yhkim/panclassif_yhk/home/"

# %%
pc.gsea(homepath) #,'BLCA')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 pc.gsea(homepath)
#
# File ~/.local/lib/python3.10/site-packages/panclassif/gseapy.py:45, in gsea(homepath)
#      42 for g in range(len(gene)):
#      43   gl.append(gene[0][g])
# ---> 45 enr = gs.enrichr(gene_list=gl, description='Disease',
#      46 	gene_sets='DisGeNET', outdir=homepath+'/enrichr')
#      47 # simple plotting function
#      48 from gseapy.plot import barplot, dotplot
#
# TypeError: enrichr() got an unexpected keyword argument 'description'

# %%
import numpy as np

# %%
df = np.load('/home/yhkim/panclassif_yhk/home/std_npy/BLCA.npy')
